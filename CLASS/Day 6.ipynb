# %%
a = int(input("enter the num 1 :"))
b = int(input("enter the num 2 : "))
c = int(input("enter the num 3 : "))

if a>b :
    print(f"the highest value is : {a}")
elif b>c:
    print(f"the highest value is : {b}")
elif c>a:
    print(f"the highest value us : {c}")
# Out:
# enter the num 1 : 55
# enter the num 2 :  99
# enter the num 3 :  88
# the highest value is : 99
