# %% [markdown]
# ## string

# %%
a = "gagagag"

print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# ## integer

# %%
b = 23

print(type(b))
# Out:
# <class 'int'>

# %% [markdown]
# ## float

# %%
i = 3.33

print(type(i))
# Out:
# <class 'float'>

# %% [markdown]
# ## complex

# %%
k = i+2j

print(type(k))
# Out:
# <class 'complex'>

# %% [markdown]
# ## boolean

# %%
f =True 

print(type(f))
# Out:
# <class 'bool'>
