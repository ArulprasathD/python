# %%
contacts = {
    "Arul": "9876543210",
    "Vignesh": "9123456780",
    "Karthik": "9012345678",
    "Rahul": "9345678901",
    "Ajay": "9567890123",
    "Suresh": "9789012345",
    "Prakash": "9890123456",
    "Manoj": "9001122334",
    "Ravi": "9112233445",
    "Dinesh": "9223344556"
}


while True:
    name = input("Enter name (type stop/quit to exit): ").capitalize()

    if name == "Stop" or name == "Quit":
        print("Program stopped")
        break

    if name in contacts:
        print("Phone number:", contacts[name])
    else:
        print("Contact not found")
# Out:
# Enter name (type stop/quit to exit):  arul
# Phone number: 9876543210
# Enter name (type stop/quit to exit):  ravi
# Phone number: 9112233445
# Enter name (type stop/quit to exit):  stop
# Program stopped
