# %%
employee = {}

while True:
    print("\n1.Add Employee")
    print("2.View Employee")
    print("3.Edit Employee")
    print("4.Delete Employee")
    print("5.Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        emp_id = int(input("Enter ID: "))
        
        if emp_id in employee:
            print("Employee already exists!")
        else:
            name = input("Enter Name: ")
            salary = int(input("Enter Salary: "))
            employee[emp_id] = {"name": name, "salary": salary}
            print("Employee Added Successfully!")

    elif choice == "2":
        if not employee:
            print("No employees found!")
        else:
            for i, j in employee.items():
                print("ID:", i, "Name:", j["name"], "Salary:", j["salary"])

    elif choice == "3":
        emp_id = int(input("Enter ID to edit: "))
        
        if emp_id in employee:
            name = input("Enter new Name: ")
            salary = int(input("Enter new Salary: "))
            employee[emp_id] = {"name": name, "salary": salary}
            print("Employee Updated Successfully!")
        else:
            print("Employee not found!")

    elif choice == "4":
        emp_id = int(input("Enter ID to delete: "))
        
        if emp_id in employee:
            del employee[emp_id]
            print("Employee Deleted Successfully!")
        else:
            print("Employee not found!")

    elif choice == "5":
        print("Exiting...")
        break

    else:
        print("Invalid Choice!")
# Out:
# 1.Add Employee
# 2.View Employee
# 3.Edit Employee
# 4.Delete Employee
# 5.Exit
# Enter choice:  1
# Enter ID:  101
# Enter Name:  ravi
# Enter Salary:  25000
# Employee Added Successfully!
#
# 1.Add Employee
# 2.View Employee
# 3.Edit Employee
# 4.Delete Employee
# 5.Exit
# Enter choice:
# Invalid Choice!
#
# 1.Add Employee
# 2.View Employee
# 3.Edit Employee
# 4.Delete Employee
# 5.Exit
# Enter choice:
# Invalid Choice!
#
# 1.Add Employee
# 2.View Employee
# 3.Edit Employee
# 4.Delete Employee
# 5.Exit
