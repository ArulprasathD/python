# %%
num=int(input("enter the number: "))
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter the number:  66
# even

# %%
mark=int(input("enter the number: "))
if ("a>=90"):
    print("grade A")
elif ("a>=75"):
    print("grade B")
elif ("a>=55"):
    print("grade C")
elif ("a>=35"):
    print("grade D")
else:
    print("grade f")
# Out:
# enter the number:  55
# grade A

# %%
num = int(input("enter the number: "))
if("num>=0"):
    print("positive")
elif ("num<=0"):
    print("negative")
else:
    print("zero")
# Out:
# enter the number:  0
# positive

# %%
year = int(input("enter year: "))
if (year % 400 == 0):
    print("leap year")
else:
    print("not a leap year")
# Out:
# enter year:  500
# not a leap year

# %%
a = int(input("enter a: "))
b = int(input("enter b: "))
c = int(input("enter c: "))
print("smaller:", min(a,b,c))
# Out:
# enter a:  44
# enter b:  66
# enter c:  77
# smaller: 44

# %%
password = input("enter password: ")
if password == "python123":
    print("access granted")
else:
    print("access denied")
# Out:
# enter password:   "python123"
# access denied

# %%
a=float(input("enter the first number: "))
op=input("enter the operator (+,-,*,%)")
b=float(input("enter the second number: "))
if op == "+":
    print(a+b)
elif op == "-":
    print(a-b)
elif op == "*":
    print(a*b)
elif op == "/":
    print(a/b)
else:
    print("invalid operator")
# Out:
# enter the first number:  5
# enter the operator (+,-,*,%) +
# enter the second number:  8
# 13.0

# %%
age=(int(input("enter the age: ")))
if age>=18:
    print("eligible")
else:
    print("not eligible")
# Out:
# enter the age:  3
# not eligible

# %%
ch = input("Enter the character: ").lower()

if ch in "aeiou":
    print("Vowel")
elif ch in "bcdfghjklmnpqrstvwxyz":
    print("Consonant")
else:
    print("Others")
# Out:
# Enter the character:  R
# Consonant

# %%
day=(input("enter the day: "))
if day in["weekend", "weekday"]:
    print("weekend")
else:
    print("weekday")
# Out:
# enter the day:  wednesday
# weekday

# %%
l=[1,22,3,44,55,6,11,1200]
l.insert(6,4)
print(l)
# Out:
# [1, 22, 3, 44, 55, 6, 4, 11, 1200]

# %%
l.remove(44)
print(l)
# Out:
# [1, 22, 6, 4, 11, 1200]

# %%
l.append(88)
print(l)
# Out:
# [1, 22, 6, 4, 11, 1200, 88]

# %%
l.pop(2)
print(l)
# Out:
# [1, 22, 4, 11, 1200, 88]

# %%
m = [1, 2, 3, 546]
l.extend(m)
print(l)
# Out:
# [1, 22, 4, 11, 1200, 88, 1, 2, 3, 546]

# %%
s="HelloWorld"
s=s[:6] +"python"+ s[6:]
print(s)
# Out:
# HelloWpythonorld

# %%
s = s.replace("World", "")
print(s)
# Out:
# HelloWpythonorld

# %%
s=s+"2024"
print(s)
# Out:
# HelloWpythonorld2024

# %%
s = s[:2] + s[3:]
print(s)
# Out:
# HeloWpythonorld2024

# %%
t="programming"
s=s+t
print(s)
# Out:
# HeloWpythonorld2024programming

# %%
mark=int(input("enter your mark (0-100): "))
if mark < 0 or mark > 100:
    print("invalid mark")
elif mark >90:
    print("grade A")
elif mark >75:
    print("grade B")
elif mark >60:
    print("grade C")
elif mark >55:
    print("grade D")
else:
    print("grade E")
# Out:
# enter your mark (0-100):  88
# grade B

# %%
ch = input("Enter a character: ").lower()

if ch.isalpha():
    if ch in "aeiou":
        print("Vowel")
    else:
        print("Consonant")
else:
    print("Not an alphabet")
# Out:
# Enter a character:  a
# Vowel

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful ✅")
else:
    print("Invalid Username or Password ❌")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful ✅
