# %%
class instagram:
    def __init__(self):
        self.username = "aruuulllll / pubilc"
        self.__password = "a1r2u3l4 / private"
        self._email = "arxxxxx@gmail.com / protected"

    def details(self):
        print("user details")
        print("USERNAME : ",self.username)
        print("PASSWORD : ",self.__password)
        print("EMAIL :",self._email)

class users(instagram):
    def profile(self):
        print("profile visit")
        print("USERNAME : ",self.username)
        print("EMAIL :",self._email)
        try:
            print("PASSWORD : ",self.__password)
        except AttributeError:
            print("NO access")
class other:
    def accesss(self):
        print("illigal")
        print("USERNAME : ",self.username)
        print("EMAIL :",self._email)
        try:
            print("PASSWORD : ",self.__password)
        except AttributeError:
            print("NO access")
        
j = instagram()
j1 = users()
j2 = other()

print("\n >> details <<")

j.details()

print("\n >> profile <<")

j1.profile()

print("\n >> other <<")

j2.accesss(j)
# Out:
#  >> details <<
# user details
# USERNAME :  aruuulllll / pubilc
# PASSWORD :  a1r2u3l4 / private
# EMAIL : arxxxxx@gmail.com / protected
#
#  >> profile <<
# profile visit
# USERNAME :  aruuulllll / pubilc
# EMAIL : arxxxxx@gmail.com / protected
# NO access
#
#  >> other <<
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 46
#      42 j1.profile()
#      44 print("\n >> other <<")
# ---> 46 j2.accesss(j)
#
# TypeError: other.accesss() takes 1 positional argument but 2 were given
